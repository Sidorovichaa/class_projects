# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 8.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 KB ? eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 7.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 899.5/899.5 KB 4.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib.image as image

# %%
import matplotlib.pyplot as plt

# %%
i = image.imread('Сидорович Анна.jpg')

# %%
plt.imshow(i)

# %%
plt.subplot(2, 2, 1)
plt.imshow(i)

# %%
plt.subplot(2, 2, 2)
gray = i[:,:,0]
plt.imshow(gray).set_cmap('gray')

# %%
plt.subplot(2, 2, 3)
plt.imshow(gray).set_cmap('Blues_r')

# %%
plt.subplot(2, 2, 4)
plt.imshow(gray).set_cmap('viridis')

# %%
plt.show()
