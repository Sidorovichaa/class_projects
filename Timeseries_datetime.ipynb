# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.4.3-cp39-cp39-win_amd64.whl (10.6 MB)
# Collecting numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10"
#   Downloading numpy-1.23.2-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anna\repos\class_projects\ve\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# Requirement already satisfied: six>=1.5 in d:\anna\repos\class_projects\ve\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: numpy, pytz, pandas
# Successfully installed numpy-1.23.2 pandas-1.4.3 pytz-2022.2.1
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'd:\anna\repos\class_projects\ve\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv('ftp://ftp.ngdc.noaa.gov/STP/SOLAR_DATA/SUNSPOT_NUMBERS/GROUP_SUNSPOT_NUMBERS/dailyrg.dat')

# %%
link = 'ftp://ftp.ngdc.noaa.gov/STP/SOLAR_DATA/SUNSPOT_NUMBERS/GROUP_SUNSPOT_NUMBERS/dailyrg.dat'

# %%
with open(link) as f:
    data = f.read(10000)

# %%
import ftplib

# %%
ftp = ftplib.FTP("ftp.ngdc.noaa.gov")

# %%
ftp.cwd('/STP/SOLAR_DATA/SUNSPOT_NUMBERS/GROUP_SUNSPOT_NUMBERS/dailyrg.dat')
# Out:
# ---------------------------------------------------------------------------
# error_perm                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 ftp.cwd('/STP/SOLAR_DATA/SUNSPOT_NUMBERS/GROUP_SUNSPOT_NUMBERS/dailyrg.dat')
#
# File C:\Program Files\Python39\lib\ftplib.py:625, in FTP.cwd(self, dirname)
#     623     dirname = '.'  # does nothing, but could return error
#     624 cmd = 'CWD ' + dirname
# --> 625 return self.voidcmd(cmd)
#
# File C:\Program Files\Python39\lib\ftplib.py:286, in FTP.voidcmd(self, cmd)
#     284 """Send a command and expect a response beginning with '2'."""
#     285 self.putcmd(cmd)
# --> 286 return self.voidresp()
#
# File C:\Program Files\Python39\lib\ftplib.py:259, in FTP.voidresp(self)
#     257 def voidresp(self):
#     258     """Expect a response beginning with '2'."""
# --> 259     resp = self.getresp()
#     260     if resp[:1] != '2':
#     261         raise error_reply(resp)
#
# File C:\Program Files\Python39\lib\ftplib.py:254, in FTP.getresp(self)
#     252     raise error_temp(resp)
#     253 if c == '5':
# --> 254     raise error_perm(resp)
#     255 raise error_proto(resp)
#
# error_perm: 530 Please login with USER and PASS.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')

# %%
df.dtypes
# Out:
# ds     object
# y     float64
# dtype: object

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\anna\repos\class_projects\ve\lib\site-packages (3.5.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (4.36.0)
# Requirement already satisfied: six>=1.5 in d:\anna\repos\class_projects\ve\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'd:\anna\repos\class_projects\ve\scripts\python.exe -m pip install --upgrade pip' command.
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: packaging>=20.0 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (1.23.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anna\repos\class_projects\ve\lib\site-packages (from matplotlib) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.36.0-py3-none-any.whl (950 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp39-cp39-win_amd64.whl (3.3 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in d:\anna\repos\class_projects\ve\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, pillow, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.36.0 kiwisolver-1.4.4 matplotlib-3.5.3 pillow-9.2.0
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'd:\anna\repos\class_projects\ve\scripts\python.exe -m pip install --upgrade pip' command.

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#               ds          y
# 0     2007-12-10   9.590761
# 1     2007-12-11   8.519590
# 2     2007-12-12   8.183677
# 3     2007-12-13   8.072467
# 4     2007-12-14   7.893572
# ...          ...        ...
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374
#
# [2905 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2905 entries, 0 to 2904
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      2905 non-null   object
#  1   y       2905 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 45.5+ KB

# %%
df['date'] = pd.to_datetime(df['ds'])

# %%
df.dtypes
# Out:
# ds              object
# y              float64
# date    datetime64[ns]
# dtype: object

# %%
df
# Out:
#               ds          y       date
# 0     2007-12-10   9.590761 2007-12-10
# 1     2007-12-11   8.519590 2007-12-11
# 2     2007-12-12   8.183677 2007-12-12
# 3     2007-12-13   8.072467 2007-12-13
# 4     2007-12-14   7.893572 2007-12-14
# ...          ...        ...        ...
# 2900  2016-01-16   7.817223 2016-01-16
# 2901  2016-01-17   9.273878 2016-01-17
# 2902  2016-01-18  10.333775 2016-01-18
# 2903  2016-01-19   9.125871 2016-01-19
# 2904  2016-01-20   8.891374 2016-01-20
#
# [2905 rows x 3 columns]

# %%
time = df['date']

# %%
time.dt.year.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.quarter.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.month.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.week.hist()
# Out:
# C:\Users\st\AppData\Local\Temp\ipykernel_11152\2562023697.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   time.dt.week.hist()
# <AxesSubplot:>

# %%
time.dt.weekday.hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.day_name().hist()
# Out:
# <AxesSubplot:>

# %%
time.dt.hour.value_counts()
# Out:
# 0    2905
# Name: date, dtype: int64

# %%
time.dt.hour.hist()
# Out:
# <AxesSubplot:>

# %%
value = df['y']

# %%
value.hist()
# Out:
# <AxesSubplot:>

# %%
cd = df.copy()

# %%
cd.index
# Out:
# RangeIndex(start=0, stop=2905, step=1)

# %%
cd.columns
# Out:
# Index(['ds', 'y', 'date'], dtype='object')

# %%
cd.index = cd['date']

# %%
cd.drop(['ds', 'date'], axis=1, inplace=True)

# %%
cd
# Out:
#                     y
# date
# 2007-12-10   9.590761
# 2007-12-11   8.519590
# 2007-12-12   8.183677
# 2007-12-13   8.072467
# 2007-12-14   7.893572
# ...               ...
# 2016-01-16   7.817223
# 2016-01-17   9.273878
# 2016-01-18  10.333775
# 2016-01-19   9.125871
# 2016-01-20   8.891374
#
# [2905 rows x 1 columns]

# %%
cd.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
diff_time = time.diff(1).dropna()

# %%
diff_time
# Out:
# 1      1 days
# 2      1 days
# 3      1 days
# 4      1 days
# 5      1 days
#         ...
# 2900   1 days
# 2901   1 days
# 2902   1 days
# 2903   1 days
# 2904   1 days
# Name: date, Length: 2904, dtype: timedelta64[ns]

# %%
diff_time.value_counts()
# Out:
# 1 days     2875
# 2 days       20
# 3 days        5
# 4 days        2
# 20 days       1
# 5 days        1
# Name: date, dtype: int64

# %%
diff_time.plot()
# Out:
# <AxesSubplot:>

# %%
dy = cd.diff(1).fillna(0)
dy
# Out:
#                    y
# date
# 2007-12-10  0.000000
# 2007-12-11 -1.071171
# 2007-12-12 -0.335914
# 2007-12-13 -0.111209
# 2007-12-14 -0.178895
# ...              ...
# 2016-01-16 -0.204690
# 2016-01-17  1.456656
# 2016-01-18  1.059897
# 2016-01-19 -1.207904
# 2016-01-20 -0.234497
#
# [2905 rows x 1 columns]

# %%
dy.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dy.mean()
# Out:
# y   -0.000241
# dtype: float64

# %%
dy.std()
# Out:
# y    0.48998
# dtype: float64

# %%
dy.hist(bins=24)
# Out:
# array([[<AxesSubplot:title={'center':'y'}>]], dtype=object)

# %%
cd.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
period = 7    #days

# %%
rd = cd.rolling(period).mean().dropna()

# %%
import matplotlib.pyplot as plt

# %%
period = 7    #days
rd = cd.rolling(period).mean().dropna()
rd.plot()
plt.title(period);

# %%
period = 30    #days
rd = cd.rolling(period).mean().dropna()
rd.plot()
plt.title(period);

# %%
period = 90    #days
rd = cd.rolling(period).mean().dropna()
rd.plot()
plt.title(period);

# %%
period = 365    #days
rd = cd.rolling(period).mean().dropna()
rd.plot()
plt.title(period);

# %%
period = 365*4    #days
rd = cd.rolling(period).mean().dropna()
rd.plot()
plt.title(period);

# %%
period = 30    #days
rd = cd.rolling(period).sum().dropna()
rd.plot()
plt.title(period);

# %%
ed = cd.expanding(1).mean()
ed.plot()
plt.title(1);

# %%
ed = cd.expanding(7).mean()
ed.plot()
plt.title(7);

# %%
ed = cd.expanding(30).mean()
ed.plot()
plt.title(30);
